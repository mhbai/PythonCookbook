# %%
# 讀 Excel 檔
import xlrd,json
wbr = xlrd.open_workbook('data/test.xls')
Table={}
# test.xls
shr = wbr.sheet_by_index(0)
for row_i in range(0,shr.nrows):
	for col_i in range(0,shr.ncols):
		data=shr.cell(row_i,col_i).value.strip()
		print data
# Out:
# 檔名
# 內容
# CRIE
# 李明懿老師
# 李嘉真老師
# 孫懿芬老師
# 陳懷萱老師
# 楊尤媛老師
# 0033.txt
# 花燈的製作，雖然精益求精，不斷的有所翻新，但是在樣式上可以歸為二大類：一類是仿照事物形象而製作的形象燈；一類是根據民間故事製作的活動燈。
# 形象燈有走獸、飛鳥、魚龍、花果的不同。走獸又有麒麟、駿馬、牛羊、獅子、猛虎等；飛鳥又有孔雀、鳳凰、仙鶴、飛燕、鴛鴦等；魚龍又有蝦、蟹、蛇、蚌、金魚、鯉魚等；花果又有荷、葡萄、牡丹、西瓜、柑橘等。
# 活動燈絕大部份取材民間故事，如老子騎青年、張果老倒騎盧，劉海戲蟾、嫦娥奔月、牛郎織女、桃園三結義、呂洞賓三戲白牡丹、武松打虎等等。
# 還有一種是按照十二生肖的順序，每年變化花燈重點的。譬如今年是豬年，就以豬燈為重點來製作，如豬八戒招親，承宮牧豬等。到了鼠年，就製作以老鼠為重點的花燈，如五鼠鬧東京，老鼠嫁女兒。其他如牛年製作火牛陣，牛郎織女，孫悟空大戰牛魔王等花燈。虎年就製作武松打虎，李廣射虎，孫思邈騎虎等的花燈。
# 製作花燈，是一種精巧的技藝，首先是用竹篾結紮燈架，糊貼上等白紙。等漿糊乾了以後，用火籠煎熬小碗的羊脂油或洋蠟燭油，讓它融化成液。用乾淨的白筆，蘸羊油在白紙燈上畫人物、山水或花卉，填上各種顏色。妙處是羊油等液，在凝結時能夠隔水，所以在同一盞花燈上，可以分成各種新色。這樣做成的花燈既透明又兼防雨，實在十分巧妙。
# C1
# C1
# C1
# B2
# C1
# c2
# 0064.txt
# 臺灣自一九八七年公佈解除戒嚴後，臺灣的社會發生了很大的變化。最大的變化應該是媒體的公開化及自由化。解嚴後，報社由十幾家增加到七十幾家，電視頻道也不再是原來三台的天下了。
# 說到電視免不了要談到廣告。因為當代人們有太多的選擇，為了要推銷一個新的產品，廣告公司得挖空心思。年輕人是媒體設定的目標，只要能把握年輕人的心，新產品就很暢銷。「新新人類」總是想盡方法打破傳統，廣告就衝破了傳統的包裹，在設計上及語言上多做變化。廣告中可以看到年輕人的喜好、社會上語言的使用、人們的價值觀等。有許多的廣告台詞到後來都成了家喻戶曉的「名言」。
# ...

# %%
# 寫 Excel 檔
from xlwt import Workbook

wbw = Workbook()
shw = wbw.add_sheet(u'情境對應表')
shw.write(0,0,u"序號")
shw.write(0,1,u"詞語")
shw.write(0,2,u"華測任務領域")
shw.write(0,3,u"華測詞類")
shw.write(0,4,u"詞庫1.0情境範疇")
shw.write(0,5,u"詞庫1.0詞類")
row_i = 1
for item in basicL:
	shw.write(row_i,0,item[0])
	shw.write(row_i,1,item[1])
	shw.write(row_i,2,item[2])
	shw.write(row_i,3,item[3])
	shw.write(row_i,4,item[4])
	shw.write(row_i,5,item[5])
	row_i += 1

wbw.save("data/test.xls")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-97ef94d6185f> in <module>()
#      11 sh.write(0,5,u"詞庫1.0詞類")
#      12 row_i = 1
# ---> 13 for item in basicL:
#      14         sh.write(row_i,0,item[0])
#      15         sh.write(row_i,1,item[1])
#
# NameError: name 'basicL' is not defined
